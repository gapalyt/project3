# %%
pip install pdfminer.six openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# 기재부 pdf 파일 텍스트를 excel 파일로 저장
from pdfminer.high_level import extract_text
from openpyxl import Workbook
import os
import re

# PDF에서 텍스트 추출
def extract_text_from_pdf(pdf_path):
    return extract_text(pdf_path)

# 허용되지 않는 문자들을 제거하는 함수
def remove_illegal_chars(text):
    ILLEGAL_CHARACTERS_RE = re.compile(r'[\000-\010]|[\013-\014]|[\016-\037]')
    return ILLEGAL_CHARACTERS_RE.sub("", text)

# 텍스트를 Excel 파일로 저장
def save_text_to_excel(text, excel_path):
    wb = Workbook()
    ws = wb.active

    lines = text.split("\n")
    for i, line in enumerate(lines, start=1):
        cleaned_line = remove_illegal_chars(line)
        ws.cell(row=i, column=1, value=cleaned_line)

    wb.save(excel_path)

if __name__ == "__main__":
    input_dir = "C:\\Users\\82104\\Downloads\\기재부\\pdf"
    output_dir = "C:\\Users\\82104\\Downloads\\기재부\\excel"

    # PDF 디렉터리 내의 모든 파일을 검색합니다.
    for filename in os.listdir(input_dir):
        if filename.endswith(".pdf"):
            pdf_path = os.path.join(input_dir, filename)
            excel_filename = os.path.splitext(filename)[0] + ".xlsx"
            excel_path = os.path.join(output_dir, excel_filename)

            extracted_text = extract_text_from_pdf(pdf_path)
            save_text_to_excel(extracted_text, excel_path)

    print("다 되었습니다.")

# %%
pip install pyhwp
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# 기재부 hwp 파일 텍스트를 excel 파일로 저장
from openpyxl import Workbook
import os
import re
import subprocess

# HWP에서 텍스트 추출
def extract_text_from_hwp(hwp_path):
    try:
        # hwp5txt 명령을 사용하여 텍스트를 추출합니다.
        result = subprocess.run(['hwp5txt', hwp_path], capture_output=True, text=True, encoding='utf-8', check=True)
        return result.stdout
    except subprocess.CalledProcessError as e:
        print(f"Error executing hwp5txt: {e}")
        print("추가적인 오류 정보:")
        print(e.stdout)  # 명령의 표준 출력
        print(e.stderr)  # 명령의 표준 오류 출력
    return ""

# 허용되지 않는 문자들을 제거하는 함수
def remove_illegal_chars(text):
    ILLEGAL_CHARACTERS_RE = re.compile(r'[\000-\010]|[\013-\014]|[\016-\037]')
    return ILLEGAL_CHARACTERS_RE.sub("", text)

# 텍스트를 Excel 파일로 저장
def save_text_to_excel(text, excel_path):
    wb = Workbook()
    ws = wb.active

    lines = text.split("\n")
    for i, line in enumerate(lines, start=1):
        cleaned_line = remove_illegal_chars(line)
        ws.cell(row=i, column=1, value=cleaned_line)

    wb.save(excel_path)

if __name__ == "__main__":
    input_dir = "C:\\Users\\82104\\Downloads\\기재부\\hwp"
    output_dir = "C:\\Users\\82104\\Downloads\\기재부\\excel"

    # HWP 디렉터리 내의 모든 파일을 검색합니다.
    for filename in os.listdir(input_dir):
        if filename.endswith(".hwp"):
            hwp_path = os.path.join(input_dir, filename)
            excel_filename = os.path.splitext(filename)[0] + ".xlsx"
            excel_path = os.path.join(output_dir, excel_filename)

            extracted_text = extract_text_from_hwp(hwp_path)
            save_text_to_excel(extracted_text, excel_path)

    print("다 되었습니다.")
# Out:
# 다 되었습니다.

# %%
# 금융위 pdf 파일 텍스트를 excel 파일로 저장
from pdfminer.high_level import extract_text
from openpyxl import Workbook
import os
import re

# PDF에서 텍스트 추출
def extract_text_from_pdf(pdf_path):
    return extract_text(pdf_path)

# 허용되지 않는 문자들을 제거하는 함수
def remove_illegal_chars(text):
    ILLEGAL_CHARACTERS_RE = re.compile(r'[\000-\010]|[\013-\014]|[\016-\037]')
    return ILLEGAL_CHARACTERS_RE.sub("", text)

# 텍스트를 Excel 파일로 저장
def save_text_to_excel(text, excel_path):
    wb = Workbook()
    ws = wb.active

    lines = text.split("\n")
    for i, line in enumerate(lines, start=1):
        cleaned_line = remove_illegal_chars(line)
        ws.cell(row=i, column=1, value=cleaned_line)

    wb.save(excel_path)

if __name__ == "__main__":
    input_dir = "C:\\Users\\82104\\Downloads\\금융위\\pdf"
    output_dir = "C:\\Users\\82104\\Downloads\\금융위\\excel"

    # PDF 디렉터리 내의 모든 파일을 검색합니다.
    for filename in os.listdir(input_dir):
        if filename.endswith(".pdf"):
            pdf_path = os.path.join(input_dir, filename)
            excel_filename = os.path.splitext(filename)[0] + ".xlsx"
            excel_path = os.path.join(output_dir, excel_filename)

            extracted_text = extract_text_from_pdf(pdf_path)
            save_text_to_excel(extracted_text, excel_path)

    print("다 되었습니다.")
# Out:
# 다 되었습니다.

# %%
# 산통부 pdf 파일 텍스트를 excel 파일로 저장
import PyPDF2
from openpyxl import Workbook
import os
import re

# PDF에서 텍스트 추출
def extract_text_from_pdf(pdf_path):
    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        text = ""
        for page in reader.pages:
            text += page.extract_text()
    return text

# 허용되지 않는 문자들을 제거하는 함수
def remove_illegal_chars(text):
    # 엑셀과 XML에서 유효하지 않은 문자 제거
    ILLEGAL_CHARACTERS_RE = re.compile(r'[\000-\010]|[\013-\014]|[\016-\037]|[\x00-\x08\x0b\x0c\x0e-\x1f\x7f-\x84\x86-\x9f\ud800-\udfff\ufdd0-\ufddf\ufffe\uffff]')
    return ILLEGAL_CHARACTERS_RE.sub("", text)

# 텍스트를 Excel 파일로 저장
def save_text_to_excel(text, excel_path):
    wb = Workbook()
    ws = wb.active

    lines = text.split("\n")
    for i, line in enumerate(lines, start=1):
        cleaned_line = remove_illegal_chars(line)
        ws.cell(row=i, column=1, value=cleaned_line)

    wb.save(excel_path)

if __name__ == "__main__":
    input_dir = "C:\\Users\\82104\\Downloads\\산통부\\pdf"
    output_dir = "C:\\Users\\82104\\Downloads\\산통부\\excel"

    # PDF 디렉터리 내의 모든 파일을 검색합니다.
    for filename in os.listdir(input_dir):
        if filename.endswith(".pdf"):
            pdf_path = os.path.join(input_dir, filename)
            excel_filename = os.path.splitext(filename)[0] + ".xlsx"
            excel_path = os.path.join(output_dir, excel_filename)

            extracted_text = extract_text_from_pdf(pdf_path)
            if extracted_text:
                save_text_to_excel(extracted_text, excel_path)

    print("다 되었습니다.")
# Out:
# 다 되었습니다.

# %%
# 기재부 hwp 파일 텍스트를 excel 파일로 저장
from openpyxl import Workbook
import os
import re
import subprocess

# HWP에서 텍스트 추출
def extract_text_from_hwp(hwp_path):
    try:
        result = subprocess.run(['hwp5txt', hwp_path], capture_output=True, text=True, encoding='utf-8', check=True)
        return result.stdout
    except subprocess.CalledProcessError as e:
        print(f"Error executing hwp5txt: {e}")
        print("추가적인 오류 정보:")
        print(e.stdout)
        print(e.stderr)
    return ""

# 허용되지 않는 문자들을 제거하는 함수
def remove_illegal_chars(text):
    # 엑셀과 XML에서 유효하지 않은 문자 제거
    ILLEGAL_CHARACTERS_RE = re.compile(r'[\000-\010]|[\013-\014]|[\016-\037]|[\x00-\x08\x0b\x0c\x0e-\x1f\x7f-\x84\x86-\x9f\ud800-\udfff\ufdd0-\ufddf\ufffe\uffff]')
    return ILLEGAL_CHARACTERS_RE.sub("", text)

# 텍스트를 Excel 파일로 저장
def save_text_to_excel(text, excel_path):
    wb = Workbook()
    ws = wb.active

    lines = text.split("\n")
    for i, line in enumerate(lines, start=1):
        cleaned_line = remove_illegal_chars(line)
        ws.cell(row=i, column=1, value=cleaned_line)

    wb.save(excel_path)

if __name__ == "__main__":
    input_dir = "C:\\Users\\82104\\Downloads\\산통부\\hwp"
    output_dir = "C:\\Users\\82104\\Downloads\\산통부\\excel"

    # HWP 디렉터리 내의 모든 파일을 검색합니다.
    for filename in os.listdir(input_dir):
        if filename.endswith(".hwp"):
            hwp_path = os.path.join(input_dir, filename)
            excel_filename = os.path.splitext(filename)[0] + ".xlsx"
            excel_path = os.path.join(output_dir, excel_filename)

            extracted_text = extract_text_from_hwp(hwp_path)
            save_text_to_excel(extracted_text, excel_path)

    print("다 되었습니다.")
# Out:
# 다 되었습니다.

# %%
# 환경부 pdf 파일 텍스트를 excel 파일로 저장
import PyPDF2
from openpyxl import Workbook
import os
import re

# PDF에서 텍스트 추출
def extract_text_from_pdf(pdf_path):
    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        text = ""
        for page in reader.pages:
            text += page.extract_text()
    return text

# 허용되지 않는 문자들을 제거하는 함수
def remove_illegal_chars(text):
    # 엑셀과 XML에서 유효하지 않은 문자 제거
    ILLEGAL_CHARACTERS_RE = re.compile(r'[\000-\010]|[\013-\014]|[\016-\037]|[\x00-\x08\x0b\x0c\x0e-\x1f\x7f-\x84\x86-\x9f\ud800-\udfff\ufdd0-\ufddf\ufffe\uffff]')
    return ILLEGAL_CHARACTERS_RE.sub("", text)

# 텍스트를 Excel 파일로 저장
def save_text_to_excel(text, excel_path):
    wb = Workbook()
    ws = wb.active

    lines = text.split("\n")
    for i, line in enumerate(lines, start=1):
        cleaned_line = remove_illegal_chars(line)
        ws.cell(row=i, column=1, value=cleaned_line)

    wb.save(excel_path)

if __name__ == "__main__":
    input_dir = "C:\\Users\\82104\\Downloads\\환경부\\pdf"
    output_dir = "C:\\Users\\82104\\Downloads\\환경부\\excel"

    # PDF 디렉터리 내의 모든 파일을 검색합니다.
    for filename in os.listdir(input_dir):
        if filename.endswith(".pdf"):
            pdf_path = os.path.join(input_dir, filename)
            excel_filename = os.path.splitext(filename)[0] + ".xlsx"
            excel_path = os.path.join(output_dir, excel_filename)

            extracted_text = extract_text_from_pdf(pdf_path)
            if extracted_text:
                save_text_to_excel(extracted_text, excel_path)

    print("다 되었습니다.")
# Out:
# 다 되었습니다.

# %%
# 환경부 hwp 파일 텍스트를 excel 파일로 저장
from openpyxl import Workbook
import os
import re
import subprocess

# HWP에서 텍스트 추출
def extract_text_from_hwp(hwp_path):
    try:
        result = subprocess.run(['hwp5txt', hwp_path], capture_output=True, text=True, encoding='utf-8', check=True)
        return result.stdout
    except subprocess.CalledProcessError as e:
        print(f"Error executing hwp5txt: {e}")
        print("추가적인 오류 정보:")
        print(e.stdout)
        print(e.stderr)
    return ""

# 허용되지 않는 문자들을 제거하는 함수
def remove_illegal_chars(text):
    # 엑셀과 XML에서 유효하지 않은 문자 제거
    ILLEGAL_CHARACTERS_RE = re.compile(r'[\000-\010]|[\013-\014]|[\016-\037]|[\x00-\x08\x0b\x0c\x0e-\x1f\x7f-\x84\x86-\x9f\ud800-\udfff\ufdd0-\ufddf\ufffe\uffff]')
    return ILLEGAL_CHARACTERS_RE.sub("", text)

# 텍스트를 Excel 파일로 저장
def save_text_to_excel(text, excel_path):
    wb = Workbook()
    ws = wb.active

    lines = text.split("\n")
    for i, line in enumerate(lines, start=1):
        cleaned_line = remove_illegal_chars(line)
        ws.cell(row=i, column=1, value=cleaned_line)

    wb.save(excel_path)

if __name__ == "__main__":
    input_dir = "C:\\Users\\82104\\Downloads\\환경부\\hwp"
    output_dir = "C:\\Users\\82104\\Downloads\\환경부\\excel"

    # HWP 디렉터리 내의 모든 파일을 검색합니다.
    for filename in os.listdir(input_dir):
        if filename.endswith(".hwp"):
            hwp_path = os.path.join(input_dir, filename)
            excel_filename = os.path.splitext(filename)[0] + ".xlsx"
            excel_path = os.path.join(output_dir, excel_filename)

            extracted_text = extract_text_from_hwp(hwp_path)
            save_text_to_excel(extracted_text, excel_path)

    print("다 되었습니다.")
# Out:
# 다 되었습니다.

# %%
# 환경부 pdf 파일 텍스트를 excel 파일로 저장
import PyPDF2
from openpyxl import Workbook
import os
import re

# PDF에서 텍스트 추출
def extract_text_from_pdf(pdf_path):
    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        text = ""
        for page in reader.pages:
            text += page.extract_text()
    return text

# 허용되지 않는 문자들을 제거하는 함수
def remove_illegal_chars(text):
    # 엑셀과 XML에서 유효하지 않은 문자 제거
    ILLEGAL_CHARACTERS_RE = re.compile(r'[\000-\010]|[\013-\014]|[\016-\037]|[\x00-\x08\x0b\x0c\x0e-\x1f\x7f-\x84\x86-\x9f\ud800-\udfff\ufdd0-\ufddf\ufffe\uffff]')
    return ILLEGAL_CHARACTERS_RE.sub("", text)

# 텍스트를 Excel 파일로 저장
def save_text_to_excel(text, excel_path):
    wb = Workbook()
    ws = wb.active

    lines = text.split("\n")
    for i, line in enumerate(lines, start=1):
        cleaned_line = remove_illegal_chars(line)
        ws.cell(row=i, column=1, value=cleaned_line)

    wb.save(excel_path)

if __name__ == "__main__":
    input_dir = "C:\\Users\\82104\\Downloads\\환경부\\after_pdf"
    output_dir = "C:\\Users\\82104\\Downloads\\환경부\\after_excel"

    # PDF 디렉터리 내의 모든 파일을 검색합니다.
    for filename in os.listdir(input_dir):
        if filename.endswith(".pdf"):
            pdf_path = os.path.join(input_dir, filename)
            excel_filename = os.path.splitext(filename)[0] + ".xlsx"
            excel_path = os.path.join(output_dir, excel_filename)

            extracted_text = extract_text_from_pdf(pdf_path)
            if extracted_text:
                save_text_to_excel(extracted_text, excel_path)

    print("다 되었습니다.")
# Out:
# 다 되었습니다.
